# %% [markdown]
# # Lattice module: `lattice.py`

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import gbtk.lattice as lattice
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# This module contains a definition of a crystal lattice. It holds an array that defines the edges of the three sets of sides of a parallelipiped (vectors in rows), an array holding the fractional coordinates of the atoms in the unit cell and an array to store the types of the atoms.
#
# Not all lattice types are currently supported. You can find out which by running the following command:

# %%
lattice.print_supported_types()
# Out:
# currently supported lattice types are:
# ['fcc', 'bcc', 'sc', 'fcc-bct', 'hcp', 'hcp-ortho', 'CsCl', 'ZrO2-fct']

# %% [markdown]
# ## Define and visualise a lattice
# Making use of this module is simply a matter of creating a lattice of a given type.

# %%
test_lattice = lattice.Lattice('fcc')

# %%
test_lattice.print_lattice_spec()
# Out:
# Details of lattice
# ------------------
# Lattice type:
# fcc
#
# Cell vectors:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
#
# Number of atoms in basis:
# 4
#
# Atom types:
# [1 1 1 1]
#
# Number of atom types
# 1
# Positions of atoms
# [[0.  0.  0. ]
#  [0.5 0.5 0. ]
#  [0.  0.5 0.5]
#  [0.5 0.  0.5]]

# %% [markdown]
# or visualise the lattice unit cell in a 3D plot:

# %%
test_lattice.visualise_3d()
# Out:
# <div>                            <div id="27b2f972-15eb-459c-9642-24699be19e44" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27b2f972-15eb-459c-9642-24699be19e44")) {                    Plotly.newPlot(                        "27b2f972-15eb-459c-9642-24699be19e44",                        [{"marker":{"color":"rgb(155, 0, 0)","size":5},"mode":"markers","name":"Atom type 1","x":[0.0,0.5,0.0,0.5],"y":[0.0,0.5,0.5,0.0],"z":[0.0,0.0,0.5,0.5],"type":"scatter3d"},{"line":{"color":"rgb(0, 0, 0)","width":2},"mode":"lines","name":"Unit cell","x":[0.0,1.0,null,0.0,0.0,null,0.0,0.0,null,1.0,1.0,null,0.0,1.0,null,1.0,1.0,null,0.0,1.0,null,0.0,0.0,null,0.0,1.0,null,1.0,1.0,null,1.0,1.0,null,0.0,0.0,null],"y":[0.0,0.0,null,0.0,1.0,null,0.0,0.0,null,0.0,1.0,null,
# ...

# %% [markdown]
# Some lattice types require extra parameters or can be specified in several ways
#
# For example, specifying the hcp lattice with no extra parameters will give a lattice with an ideal c/a ratio by default:"

# %%
test_lattice = lattice.Lattice('hcp')

# %% [markdown]
# Alternatively, we can provide one value for the length parameter to explicitly specify the c/a ratio:

# %%
test_lattice = lattice.Lattice('hcp', lengths=[5.0])

# %% [markdown]
# We have an additional option for the hexagonal close packed lattice: we can specify a four-atom orthogonal unit cell via the lattice type 'hcp-ortho'. Note that the atomic positions in this unit cell may look a little unusual. This is because we have chosen them so that the origin is at a centre of inversion symmetry. This is important under certain circumstances when working with bicrystals.

# %%
test_lattice = lattice.Lattice('hcp-ortho')
test_lattice.visualise_3d()
# Out:
# <div>                            <div id="95e39544-b800-4fa3-8b62-f667a9d783c9" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95e39544-b800-4fa3-8b62-f667a9d783c9")) {                    Plotly.newPlot(                        "95e39544-b800-4fa3-8b62-f667a9d783c9",                        [{"marker":{"color":"rgb(155, 0, 0)","size":5},"mode":"markers","name":"Atom type 1","x":[0.75,0.25,0.25,0.75],"y":[1.5877132402714706,0.7216878364870322,0.14433756729740643,1.010362971081845],"z":[1.224744871391589,1.224744871391589,0.408248290463863,0.408248290463863],"type":"scatter3d"},{"line":{"color":"rgb(0, 0, 0)","width":2},"mode":"lines","name":"Unit cell","x":[0.0,1.0,null,0.0,0.0,null,0.0,0.0,null,1.0,1.0,null,0.0,1.0,null,1.0,1.0,null,0.0,1.0,null,0.0
# ...
